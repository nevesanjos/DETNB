# %%
from obspy import read, UTCDateTime as UTC
from obspy.signal.cross_correlation import correlation_detector

# Sismograma que contem a forma de onda desejada
###################################################
#template = read('../eventos/ref/*HHZ')
#template = read('../DADOS/2022/LS/JAC1/HHZ.D/LS.JAC1..HHZ.D.2022.063') # Jacobina
template = read('/home/felipe/sources/DADOS/NRT/2022/NB/NBCM/HHZ.D/NB.NBCM..HHZ.D.2022.130') # Armagosa
template.filter('bandpass', freqmin=2, freqmax=20)

# Picagem da primeira chegada 
###################################################
#pick = UTC('2022-03-04T02:58:58.423') # jacobina
pick = UTC('2022-05-10T07:11:14.887') # Amargosa
template.trim(pick - 1, pick + 2)

template.plot()

# Sismograma onde buscar formas de onda similares
###################################################
#stream = read('../DADOS/2022/LS/JAC1/HHZ.D/LS.JAC1..HHZ.D.2022.063')
#stream = read('/home/felipe/sources/DADOS/NRT/2022/LS/JAC1/HHZ.D/LS.JAC1..HHZ.D.2022.130')
stream = read('/home/felipe/sources/DADOS/NRT/2022/NB/NBCM/HHZ.D/NB.NBCM..HHZ.D.2022.127')

if(len(stream) > 0):
    stream.merge(fill_value='interpolate')

#if(stream[0].stats.sampling_rate > 100):
#    stream.decimate(4)

#stream.decimate(4)
stream.filter('bandpass', freqmin=2, freqmax=20)
height = 0.6  # similarity threshold
distance = 5  # distance between detections in seconds
detections, sims = correlation_detector(stream, template, height, distance, plot=stream)

path = "../eventos/"
j = "063"
import os

for d in detections:
    start = d['time']
    end = start + 3
    print(start)
    
    pasta = path + j
    if not os.path.exists(pasta + "/similar"):
        os.makedirs(pasta + "/similar")
        
    
        
    st = stream
    tr = st.copy()
    tr.trim(start, end)
                
    
                
                
    pasta = pasta + "/similar/" + str(d['time'])
    #if not os.path.exists(pasta):
    #    os.mkdir(pasta)
    tr.plot()
    #tr.write(pasta + ".HHZ", format='SAC')

# %%
import glob

files = glob.glob(path+j+"/similar/*")

# %%
for f in files:
    st = read(f)
    st.plot()
