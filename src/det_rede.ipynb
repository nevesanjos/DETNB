# %%
from obspy.core import Stream, read
from obspy.signal.trigger import coincidence_trigger
from obspy.signal.trigger import classic_sta_lta
from obspy.signal.trigger import plot_trigger, trigger_onset

from pprint import pprint
import glob
import os
import sys

############################################################
# Dia juliano
j = "130"

# Caminho para os Dados
dados = "/home/felipe/sources/DADOS/NRT/2022/"
#dados = "../DADOS/2022/"

# Pasta com os possíveis eventos recortados 
path = "../eventos/"

if not os.path.exists(path):
        os.mkdir(path)

##########################################
trigger_on = 5 # o código utiliza  
trigger_off = 2
sta = 0.5
lta = 10

# numero de estações minimas
n = 3
###########################################

fmin = 2
fmax = 20

# Rede e estações
rede = ['LS', 'NB']
estacoes = ['.NB']
############################################################

st = Stream()
files = []
for r in rede:
    files = files + glob.glob(dados + r + "/*/*HHZ*/*" + j)

for f in files:
    for e in estacoes:
        if(e in f):
            tr = read(f)
            if(len(tr) > 1):
                tr.merge(fill_value='interpolate')
            st += tr

#remove a tendência e filtra             
st.detrend()
st.filter('bandpass', freqmin=fmin, freqmax=fmax)

st2 = st.copy()
trig = coincidence_trigger("recstalta", trigger_on, trigger_off, st2, n, sta=sta, lta=lta,
                          details=True)
#pprint(trig)
    
for d in trig:
    
    start = d['time'] - 5
    end = start + 15
    
    pasta = path + j
    if not os.path.exists(pasta):
        os.mkdir(pasta)
    
    if not os.path.exists(pasta + "/coincidencia/" + str(d['time'])):
        os.makedirs(pasta + "/coincidencia/" + str(d['time']))
    for s in d['stations']:
        for f in files:
            if (s in f):
                print(f) 
                st = read(f)
                tr = st.copy()
                tr.trim(start, end)
                tr.write(pasta + "/coincidencia/" + str(d['time'])+"/"+str(s) + ".HHZ", format='SAC')
                
                ff = f.replace('HHZ','HHN')
                st = read(ff)
                tr = st.copy()
                tr.trim(start, end)
                tr.write(pasta + "/coincidencia/" + str(d['time'])+"/"+str(s) + ".HHN", format='SAC')
                
                ff = f.replace('HHZ','HHE')
                ff.replace('HHN','HHE')
                st = read(ff)
                tr = st.copy()
                tr.trim(start, end)
                tr.write(pasta + "/coincidencia/" + str(d['time'])+"/"+str(s) + ".HHE", format='SAC')
# Out:
# /home/felipe/sources/DADOS/NRT/2022/NB/NBMO/HHZ.D/NB.NBMO..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBMA/HHZ.D/NB.NBMA..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBPF/HHZ.D/NB.NBPF..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBRFO/HHZ.D/NB.NBRFO..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBAN/HHZ.D/NB.NBAN..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBPB/HHZ.D/NB.NBPB..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBCM/HHZ.D/NB.NBCM..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBMO/HHZ.D/NB.NBMO..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBPB/HHZ.D/NB.NBPB..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBPB/HHZ.D/NB.NBPB..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBMA/HHZ.D/NB.NBMA..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBJCA/HHZ.D/NB.NBJCA..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBPF/HHZ.D/NB.NBPF..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBLV/HHZ.D/NB.NBLV..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBCA/HHZ.D/NB.NBCA..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBPF/HHZ.D/NB.NBPF..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBPB/HHZ.D/NB.NBPB..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBCM/HHZ.D/NB.NBCM..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBPB/HHZ.D/NB.NBPB..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBCM/HHZ.D/NB.NBCM..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBPF/HHZ.D/NB.NBPF..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBMO/HHZ.D/NB.NBMO..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBCM/HHZ.D/NB.NBCM..HHZ.D.2022.130
# /home/felipe/sources/DADOS/NRT/2022/NB/NBJCA/HHZ.D/NB.NBJCA..HHZ.D.2022.130
# ---------------------------------------------------------------------------
# ObsPyException                            Traceback (most recent call last)
# /tmp/ipykernel_7683/3312160303.py in <module>
#      82                 tr = st.copy()
#      83                 tr.trim(start, end)
# ---> 84                 tr.write(pasta + "/coincidencia/" + str(d['time'])+"/"+str(s) + ".HHZ", format='SAC')
#      85
#      86                 ff = f.replace('HHZ','HHN')
#
# /opt/anaconda3/lib/python3.9/site-packages/obspy/core/stream.py in write(self, filename, format, **kwargs)
#    1435         if not self.traces:
#    1436             msg = 'Can not write empty stream to file.'
# -> 1437             raise ObsPyException(msg)
#    1438
#    1439         # Check all traces for masked arrays and raise exception.
#
# ObsPyException: Can not write empty stream to file.
