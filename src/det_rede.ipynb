# %%
from obspy.core import Stream, read
from obspy.signal.trigger import coincidence_trigger
from obspy.signal.trigger import classic_sta_lta
from obspy.signal.trigger import plot_trigger, trigger_onset

from pprint import pprint
import glob
import os
import sys

############################################################
# Dia juliano
j = "063"

# Caminho para os Dados
dados = "../DADOS/2022/"

# Pasta com os possíveis eventos recortados 
path = "../eventos/"

if not os.path.exists(path):
        os.mkdir(path)

##########################################
trigger_on = 5 # o código utiliza  
trigger_off = 2
sta = 0.5
lta = 10

# numero de estações minimas
n = 4
###########################################

fmin = 2
fmax = 20

# Rede e estações
rede = ['LS', 'NB']
estacoes = ['JAC']
############################################################

st = Stream()
files = []
for r in rede:
    files = files + glob.glob(dados + r + "/*/*HHZ*/*" + j)

for f in files:
    for e in estacoes:
        if(e in f):
            tr = read(f)
            if(len(tr) > 1):
                tr.merge(fill_value='interpolate')
            st += tr

#remove a tendência e filtra             
st.detrend()
st.filter('bandpass', freqmin=fmin, freqmax=fmax)

st2 = st.copy()
trig = coincidence_trigger("recstalta", trigger_on, trigger_off, st2, n, sta=sta, lta=lta,
                          details=True)
#pprint(trig)
    
for d in trig:
    
    start = d['time'] - 5
    end = start + 15
    
    pasta = path + j
    if not os.path.exists(pasta):
        os.mkdir(pasta)
    
    if not os.path.exists(pasta + "/coincidencia/" + str(d['time'])):
        os.makedirs(pasta + "/coincidencia/" + str(d['time']))
    for s in d['stations']:
        for f in files:
            if (s in f):
                st = read(f)
                tr = st.copy()
                tr.trim(start, end)
                tr.write(pasta + "/coincidencia/" + str(d['time'])+"/"+str(s) + ".HHZ", format='SAC')
                
                ff = f.replace('HHZ','HHN')
                st = read(ff)
                tr = st.copy()
                tr.trim(start, end)
                tr.write(pasta + "/coincidencia/" + str(d['time'])+"/"+str(s) + ".HHN", format='SAC')
                
                ff = f.replace('HHZ','HHE')
                ff.replace('HHN','HHE')
                st = read(ff)
                tr = st.copy()
                tr.trim(start, end)
                tr.write(pasta + "/coincidencia/" + str(d['time'])+"/"+str(s) + ".HHE", format='SAC')

# %%
estacoes

# %%
dados

# %%
dados + r + "/*/*HHZ*/*" + j

# %% [markdown]
# # Sismologia
# ## sismo

# %%
pprint(trig)
# Out:
# [{'cft_peak_wmean': 9.6961549579298989,
#   'cft_peaks': [10.806966087981225,
#                 12.783767099745642,
#                 7.0453222186620197,
#                 8.1485644253307097],
#   'cft_std_wmean': 1.8095253626075443,
#   'cft_stds': [2.3443205960337501,
#                2.3834351360129777,
#                1.1135134695931073,
#                1.3968322487903426],
#   'coincidence_sum': 4.0,
#   'duration': 8.171000003814697,
#   'similarity': {},
#   'stations': ['JAC1', 'JAC6', 'JAC5', 'JAC4'],
#   'time': UTCDateTime(2022, 3, 4, 1, 30, 3, 680000),
#   'trace_ids': ['LS.JAC1..HHZ',
#                 'LS.JAC6..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC4..HHZ']},
#  {'cft_peak_wmean': 8.8289364767141016,
#   'cft_peaks': [6.9735806025377913,
#                 12.286803721655078,
#                 8.4065523489282956,
#                 7.6488092337352418],
#   'cft_std_wmean': 2.0954915689928186,
#   'cft_stds': [1.4098384470216849,
#                3.2508446886274163,
#                1.9975235626062569,
#                1.7237595777159169],
#   'coincidence_sum': 4.0,
#   'duration': 2.5199990272521973,
#   'similarity': {},
#   'stations': ['JAC2', 'JAC5', 'JAC4', 'JAC6'],
#   'time': UTCDateTime(2022, 3, 4, 2, 52, 24, 687000),
#   'trace_ids': ['LS.JAC2..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC4..HHZ',
#                 'LS.JAC6..HHZ']},
#  {'cft_peak_wmean': 13.133859711241252,
#   'cft_peaks': [11.927624844740652,
#                 11.058447925499422,
#                 11.916405921042164,
#                 15.649359640381043,
#                 15.117460224542979],
#   'cft_std_wmean': 2.9295745483903142,
#   'cft_stds': [2.5410623180916772,
#                2.1441160864654494,
#                2.6137033196574322,
#                3.999654218933657,
#                3.3493367988033542],
#   'coincidence_sum': 5.0,
#   'duration': 4.640999794006348,
#   'similarity': {},
#   'stations': ['JAC3', 'JAC6', 'JAC2', 'JAC5', 'JAC4'],
#   'time': UTCDateTime(2022, 3, 4, 2, 55, 52, 220000),
#   'trace_ids': ['LS.JAC3..HHZ',
#                 'LS.JAC6..HHZ',
#                 'LS.JAC2..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC4..HHZ']},
#  {'cft_peak_wmean': 14.195997990096805,
#   'cft_peaks': [11.283413669358017,
#                 14.072319586037839,
#                 18.845878796431499,
#                 17.657050595378987,
#                 9.1213273032776776],
#   'cft_std_wmean': 3.3317827570669514,
#   'cft_stds': [2.4610025016025117,
#                3.2187033811351982,
#                5.2904421642664303,
#                3.601555412317671,
#                2.0872103260129462],
#   'coincidence_sum': 5.0,
#   'duration': 4.8440001010894775,
#   'similarity': {},
#   'stations': ['JAC2', 'JAC6', 'JAC5', 'JAC4', 'JAC3'],
#   'time': UTCDateTime(2022, 3, 4, 2, 57, 41, 637000),
#   'trace_ids': ['LS.JAC2..HHZ',
#                 'LS.JAC6..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC4..HHZ',
#                 'LS.JAC3..HHZ']},
#  {'cft_peak_wmean': 18.147935232490653,
#   'cft_peaks': [15.252070393156391,
#                 18.172449250457074,
#                 19.013962777650274,
#                 19.389078032210975,
#                 18.912115708978551],
#   'cft_std_wmean': 4.2703977983879424,
#   'cft_stds': [3.506192260772528,
#                3.7002653263464613,
#                3.9435579671260825,
#                5.7353176871798466,
#                4.466655750514791],
#   'coincidence_sum': 5.0,
#   'duration': 5.111000061035156,
#   'similarity': {},
#   'stations': ['JAC3', 'JAC2', 'JAC6', 'JAC5', 'JAC4'],
#   'time': UTCDateTime(2022, 3, 4, 2, 59, 0, 320000),
#   'trace_ids': ['LS.JAC3..HHZ',
#                 'LS.JAC2..HHZ',
#                 'LS.JAC6..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC4..HHZ']},
#  {'cft_peak_wmean': 10.885248049236878,
#   'cft_peaks': [13.439058021219376,
#                 11.274746012751773,
#                 8.3853816099467071,
#                 15.989918808887818,
#                 5.3371357933787182],
#   'cft_std_wmean': 2.3533990386544543,
#   'cft_stds': [2.8562914528979868,
#                2.8965763989232047,
#                1.6505667587211281,
#                3.3502491514346251,
#                1.0133114312953282],
#   'coincidence_sum': 5.0,
#   'duration': 4.80400013923645,
#   'similarity': {},
#   'stations': ['JAC2', 'JAC5', 'JAC6', 'JAC4', 'JAC3'],
#   'time': UTCDateTime(2022, 3, 4, 3, 7, 31, 727000),
#   'trace_ids': ['LS.JAC2..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC6..HHZ',
#                 'LS.JAC4..HHZ',
#                 'LS.JAC3..HHZ']},
#  {'cft_peak_wmean': 12.781245865481358,
#   'cft_peaks': [19.540846413793133,
#                 10.776470665964929,
#                 18.558552501050908,
#                 6.7968552234544619,
#                 15.316067675659477,
#                 5.6986827129652395],
#   'cft_std_wmean': 3.0894736212006246,
#   'cft_stds': [5.6171678343437401,
#                2.0106341180939267,
#                5.0696732516631577,
#                1.1324867140228756,
#                3.574363547978054,
#                1.1325162611019925],
#   'coincidence_sum': 6.0,
#   'duration': 6.7210001945495605,
#   'similarity': {},
#   'stations': ['JAC1', 'JAC2', 'JAC5', 'JAC6', 'JAC4', 'JAC3'],
#   'time': UTCDateTime(2022, 3, 4, 3, 9, 59, 170000),
#   'trace_ids': ['LS.JAC1..HHZ',
#                 'LS.JAC2..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC6..HHZ',
#                 'LS.JAC4..HHZ',
#                 'LS.JAC3..HHZ']},
#  {'cft_peak_wmean': 10.362901015787173,
#   'cft_peaks': [12.233492139547144,
#                 14.384905177455707,
#                 8.5473723920196942,
#                 6.2858343541261412],
#   'cft_std_wmean': 2.3491260293929406,
#   'cft_stds': [2.9031054069746038,
#                3.4774023231308848,
#                1.9061621259197297,
#                1.1098342615465431],
#   'coincidence_sum': 4.0,
#   'duration': 4.3050010204315186,
#   'similarity': {},
#   'stations': ['JAC5', 'JAC4', 'JAC2', 'JAC6'],
#   'time': UTCDateTime(2022, 3, 4, 3, 25, 31, 965999),
#   'trace_ids': ['LS.JAC5..HHZ',
#                 'LS.JAC4..HHZ',
#                 'LS.JAC2..HHZ',
#                 'LS.JAC6..HHZ']},
#  {'cft_peak_wmean': 15.893548237093944,
#   'cft_peaks': [14.773941013434547,
#                 15.365804250166741,
#                 11.935518264498922,
#                 18.023065203642293,
#                 19.369412453727215],
#   'cft_std_wmean': 3.6170733394181296,
#   'cft_stds': [3.0472506373145567,
#                3.4696384584105755,
#                2.5057333943919575,
#                4.8215022964612446,
#                4.2412419105123167],
#   'coincidence_sum': 5.0,
#   'duration': 4.7809998989105225,
#   'similarity': {},
#   'stations': ['JAC3', 'JAC2', 'JAC6', 'JAC5', 'JAC4'],
#   'time': UTCDateTime(2022, 3, 4, 3, 35, 59, 720000),
#   'trace_ids': ['LS.JAC3..HHZ',
#                 'LS.JAC2..HHZ',
#                 'LS.JAC6..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC4..HHZ']},
#  {'cft_peak_wmean': 11.478549126257658,
#   'cft_peaks': [9.9708020485080535,
#                 14.958385676167444,
#                 12.016477089026392,
#                 8.9685316913287387],
#   'cft_std_wmean': 2.7099386380543904,
#   'cft_stds': [2.362832364194924,
#                4.1568459824371047,
#                2.385812888044017,
#                1.9342633175415165],
#   'coincidence_sum': 4.0,
#   'duration': 4.6140007972717285,
#   'similarity': {},
#   'stations': ['JAC6', 'JAC5', 'JAC4', 'JAC2'],
#   'time': UTCDateTime(2022, 3, 4, 5, 38, 46, 246999),
#   'trace_ids': ['LS.JAC6..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC4..HHZ',
#                 'LS.JAC2..HHZ']},
#  {'cft_peak_wmean': 11.315807983523673,
#   'cft_peaks': [15.302124704560448,
#                 12.240773150591187,
#                 6.8944250931835116,
#                 10.825908985759536],
#   'cft_std_wmean': 2.7704642023777768,
#   'cft_stds': [4.3036318609230673,
#                2.6334953213710066,
#                1.4128094150516519,
#                2.7319202121653827],
#   'coincidence_sum': 4.0,
#   'duration': 4.445000886917114,
#   'similarity': {},
#   'stations': ['JAC5', 'JAC4', 'JAC3', 'JAC2'],
#   'time': UTCDateTime(2022, 3, 4, 6, 18, 34, 615999),
#   'trace_ids': ['LS.JAC5..HHZ',
#                 'LS.JAC4..HHZ',
#                 'LS.JAC3..HHZ',
#                 'LS.JAC2..HHZ']},
#  {'cft_peak_wmean': 13.673583274792071,
#   'cft_peaks': [12.87174033078848,
#                 18.642062125387845,
#                 16.488773466687718,
#                 15.903266328850973,
#                 10.772172206384857,
#                 7.3634851906525478],
#   'cft_std_wmean': 3.2047222566885605,
#   'cft_stds': [3.2894319668937277,
#                3.8982416077006752,
#                4.202908173823257,
#                3.4797969814264484,
#                2.7173881752583648,
#                1.6405666350288899],
#   'coincidence_sum': 6.0,
#   'duration': 4.803999900817871,
#   'similarity': {},
#   'stations': ['JAC2', 'JAC6', 'JAC5', 'JAC4', 'JAC3', 'JAC1'],
#   'time': UTCDateTime(2022, 3, 4, 7, 5, 23, 177000),
#   'trace_ids': ['LS.JAC2..HHZ',
#                 'LS.JAC6..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC4..HHZ',
#                 'LS.JAC3..HHZ',
#                 'LS.JAC1..HHZ']},
#  {'cft_peak_wmean': 10.317020921631688,
#   'cft_peaks': [13.232732599082663,
#                 15.065590172362112,
#                 5.9398139953563591,
#                 7.0299469197256181],
#   'cft_std_wmean': 2.3572691561023915,
#   'cft_stds': [3.4104711469167119,
#                3.3810559723674372,
#                1.1813095328169982,
#                1.4562399723084183],
#   'coincidence_sum': 4.0,
#   'duration': 3.8730010986328125,
#   'similarity': {},
#   'stations': ['JAC6', 'JAC5', 'JAC1', 'JAC3'],
#   'time': UTCDateTime(2022, 3, 4, 7, 13, 35, 306999),
#   'trace_ids': ['LS.JAC6..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC1..HHZ',
#                 'LS.JAC3..HHZ']},
#  {'cft_peak_wmean': 10.381504385452002,
#   'cft_peaks': [11.935873454818072,
#                 8.5495553886002895,
#                 11.170501351859887,
#                 13.196180692732126,
#                 7.0554110392496394],
#   'cft_std_wmean': 2.3433831463971715,
#   'cft_stds': [2.438572424644212,
#                1.8551883992004725,
#                2.7541927988507022,
#                3.0810410379889639,
#                1.5879210713015066],
#   'coincidence_sum': 5.0,
#   'duration': 5.1299989223480225,
#   'similarity': {},
#   'stations': ['JAC2', 'JAC6', 'JAC5', 'JAC4', 'JAC3'],
#   'time': UTCDateTime(2022, 3, 4, 7, 19, 32, 227000),
#   'trace_ids': ['LS.JAC2..HHZ',
#                 'LS.JAC6..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC4..HHZ',
#                 'LS.JAC3..HHZ']},
#  {'cft_peak_wmean': 13.08042208797413,
#   'cft_peaks': [7.9657320306955741,
#                 13.447044848022196,
#                 16.944805216627977,
#                 17.953744192646926,
#                 14.900171992929865,
#                 7.271034246922242],
#   'cft_std_wmean': 2.9176724094046622,
#   'cft_stds': [1.3885453642456109,
#                3.3902828660296618,
#                3.9932449409971382,
#                4.0172367225816412,
#                3.0086759028602845,
#                1.7080486597136366],
#   'coincidence_sum': 6.0,
#   'duration': 7.364000082015991,
#   'similarity': {},
#   'stations': ['JAC2', 'JAC1', 'JAC6', 'JAC5', 'JAC4', 'JAC3'],
#   'time': UTCDateTime(2022, 3, 4, 8, 25, 40, 487000),
#   'trace_ids': ['LS.JAC2..HHZ',
#                 'LS.JAC1..HHZ',
#                 'LS.JAC6..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC4..HHZ',
#                 'LS.JAC3..HHZ']},
#  {'cft_peak_wmean': 15.574351044301295,
#   'cft_peaks': [15.944927244226529,
#                 17.068774790947661,
#                 18.979209752114119,
#                 16.790667762455126,
#                 9.0881756717630395],
#   'cft_std_wmean': 3.7769726427840196,
#   'cft_stds': [4.32272761901769,
#                4.0269379249776014,
#                4.2070834391200469,
#                4.162532530662296,
#                2.1655817001424658],
#   'coincidence_sum': 5.0,
#   'duration': 6.500999927520752,
#   'similarity': {},
#   'stations': ['JAC1', 'JAC6', 'JAC5', 'JAC4', 'JAC3'],
#   'time': UTCDateTime(2022, 3, 4, 8, 27, 52, 140000),
#   'trace_ids': ['LS.JAC1..HHZ',
#                 'LS.JAC6..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC4..HHZ',
#                 'LS.JAC3..HHZ']},
#  {'cft_peak_wmean': 16.775895186303291,
#   'cft_peaks': [17.917905170896109,
#                 18.006176259818009,
#                 19.167280271581546,
#                 11.03843885175008,
#                 17.749675377470716],
#   'cft_std_wmean': 3.8179180174288918,
#   'cft_stds': [4.2195196437708988,
#                4.145321310915941,
#                4.1020652449279922,
#                2.198101415445231,
#                4.4245824720843947],
#   'coincidence_sum': 5.0,
#   'duration': 4.7799999713897705,
#   'similarity': {},
#   'stations': ['JAC1', 'JAC6', 'JAC5', 'JAC3', 'JAC4'],
#   'time': UTCDateTime(2022, 3, 4, 8, 29, 17, 500000),
#   'trace_ids': ['LS.JAC1..HHZ',
#                 'LS.JAC6..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC3..HHZ',
#                 'LS.JAC4..HHZ']},
#  {'cft_peak_wmean': 11.764759099509616,
#   'cft_peaks': [10.299311430310057,
#                 14.108532180279184,
#                 10.423340496085922,
#                 12.222531143266115,
#                 13.264560290093538,
#                 10.270279057022879],
#   'cft_std_wmean': 2.5658716723457275,
#   'cft_stds': [2.0531613640942781,
#                2.6300553436569012,
#                2.594413259620993,
#                2.5965088872975755,
#                3.5166572067009159,
#                2.0044339727036995],
#   'coincidence_sum': 6.0,
#   'duration': 9.85700011253357,
#   'similarity': {},
#   'stations': ['JAC1', 'JAC6', 'JAC5', 'JAC3', 'JAC4', 'JAC2'],
#   'time': UTCDateTime(2022, 3, 4, 8, 29, 40, 130000),
#   'trace_ids': ['LS.JAC1..HHZ',
#                 'LS.JAC6..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC3..HHZ',
#                 'LS.JAC4..HHZ',
#                 'LS.JAC2..HHZ']},
#  {'cft_peak_wmean': 9.2353799137801627,
#   'cft_peaks': [8.343171227433368,
#                 14.004846631982454,
#                 6.6119621889688158,
#                 7.9815396067360114],
#   'cft_std_wmean': 1.9627138893241629,
#   'cft_stds': [1.7594159773658939,
#                3.3420036484180833,
#                1.2989533952407033,
#                1.4504825362719709],
#   'coincidence_sum': 4.0,
#   'duration': 6.480999946594238,
#   'similarity': {},
#   'stations': ['JAC1', 'JAC5', 'JAC6', 'JAC4'],
#   'time': UTCDateTime(2022, 3, 4, 14, 2, 20, 220000),
#   'trace_ids': ['LS.JAC1..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC6..HHZ',
#                 'LS.JAC4..HHZ']},
#  {'cft_peak_wmean': 14.227011381972847,
#   'cft_peaks': [12.024513962768975,
#                 13.371369135085089,
#                 18.741858152570668,
#                 18.790794077885305,
#                 8.2065215815542008],
#   'cft_std_wmean': 3.170902760330875,
#   'cft_stds': [2.4037866104061778,
#                2.8285723426983975,
#                5.1217674751225228,
#                3.839033494782198,
#                1.6613538786450806],
#   'coincidence_sum': 5.0,
#   'duration': 4.8409998416900635,
#   'similarity': {},
#   'stations': ['JAC3', 'JAC2', 'JAC5', 'JAC4', 'JAC6'],
#   'time': UTCDateTime(2022, 3, 4, 14, 57, 6, 400000),
#   'trace_ids': ['LS.JAC3..HHZ',
#                 'LS.JAC2..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC4..HHZ',
#                 'LS.JAC6..HHZ']},
#  {'cft_peak_wmean': 15.585034207927839,
#   'cft_peaks': [12.268814401129154,
#                 13.140805231602773,
#                 14.774939164254773,
#                 19.62594304470899,
#                 18.11466919794351],
#   'cft_std_wmean': 3.5975529750945796,
#   'cft_stds': [2.6592334261985964,
#                2.8613868443099437,
#                3.143932068808128,
#                5.5356450599657494,
#                3.7875674761904836],
#   'coincidence_sum': 5.0,
#   'duration': 5.13100004196167,
#   'similarity': {},
#   'stations': ['JAC3', 'JAC2', 'JAC6', 'JAC5', 'JAC4'],
#   'time': UTCDateTime(2022, 3, 4, 17, 25, 0, 20000),
#   'trace_ids': ['LS.JAC3..HHZ',
#                 'LS.JAC2..HHZ',
#                 'LS.JAC6..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC4..HHZ']},
#  {'cft_peak_wmean': 11.134631569584823,
#   'cft_peaks': [15.030433806991589,
#                 14.615254526931047,
#                 6.5436462645218159,
#                 8.3491916798948385],
#   'cft_std_wmean': 2.6391738419569628,
#   'cft_stds': [3.6194939924318748,
#                3.5433623419822613,
#                1.4267670979601248,
#                1.9670719354535913],
#   'coincidence_sum': 4.0,
#   'duration': 4.315001010894775,
#   'similarity': {},
#   'stations': ['JAC5', 'JAC4', 'JAC3', 'JAC2'],
#   'time': UTCDateTime(2022, 3, 4, 17, 49, 33, 825999),
#   'trace_ids': ['LS.JAC5..HHZ',
#                 'LS.JAC4..HHZ',
#                 'LS.JAC3..HHZ',
#                 'LS.JAC2..HHZ']},
#  {'cft_peak_wmean': 10.487878949889691,
#   'cft_peaks': [16.319582859977718,
#                 8.7440256643972205,
#                 7.6876176100152316,
#                 9.2002896651685866],
#   'cft_std_wmean': 2.5688490745068799,
#   'cft_stds': [4.6842657763263214,
#                2.2259313897469815,
#                1.3836546902105438,
#                1.9815444417436718],
#   'coincidence_sum': 4.0,
#   'duration': 4.475001096725464,
#   'similarity': {},
#   'stations': ['JAC5', 'JAC3', 'JAC6', 'JAC4'],
#   'time': UTCDateTime(2022, 3, 4, 19, 0, 4, 195999),
#   'trace_ids': ['LS.JAC5..HHZ',
#                 'LS.JAC3..HHZ',
#                 'LS.JAC6..HHZ',
#                 'LS.JAC4..HHZ']},
#  {'cft_peak_wmean': 17.01013003703984,
#   'cft_peaks': [18.932211099880909,
#                 16.238534134294422,
#                 19.470345190800401,
#                 11.133962809723883,
#                 19.275596950499583],
#   'cft_std_wmean': 3.9736786083762587,
#   'cft_stds': [4.6300846057337228,
#                3.7553387095054322,
#                4.2728610781543761,
#                2.3894879858280365,
#                4.820620662659727],
#   'coincidence_sum': 5.0,
#   'duration': 4.849999904632568,
#   'similarity': {},
#   'stations': ['JAC1', 'JAC6', 'JAC5', 'JAC3', 'JAC4'],
#   'time': UTCDateTime(2022, 3, 4, 23, 16, 4, 550000),
#   'trace_ids': ['LS.JAC1..HHZ',
#                 'LS.JAC6..HHZ',
#                 'LS.JAC5..HHZ',
#                 'LS.JAC3..HHZ',
#                 'LS.JAC4..HHZ']}]
